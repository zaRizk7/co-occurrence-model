# %%
# %cd -q ..
# Out:
# /home/zarizky/projects/neural-autoregressive-object-co-occurrence

# %%
from collections import OrderedDict
from copy import deepcopy
from math import log

import numpy as np
import pandas as pd
from scipy import special
from scipy.stats import poisson
from tqdm.auto import tqdm
from xgboost import XGBRegressor

# %%
np.random.seed(0)

df_train = pd.read_csv("dataset/coco2017-cooccurences-train.csv")
df_valid = pd.read_csv("dataset/coco2017-cooccurences-valid.csv")

X_train = df_train.iloc[:, 8:]
X_valid = df_valid.iloc[:, 8:]

orders = [np.random.permutation(X_train.columns) for i in range(100)]
orders = np.stack(orders)

data = []
for order in orders:
    data.append(dict(train=X_train.loc[:, order], valid=X_valid.loc[:, order]))

# %%
log_likelihood = dict(train=[], valid=[])
for data_order in (pbar := tqdm(data, unit="order")):
    model_autoreg = []
    for i in range(1, data[0]["train"].shape[-1]):
        X = data_order["train"].iloc[:, :i].to_numpy()
        y = data_order["train"].iloc[:, i].to_numpy()
        m = XGBRegressor(objective="count:poisson", random_state=0)
        m.fit(X, y)
        model_autoreg.append(deepcopy(m))

    X = data_order["train"].iloc[:, :1].to_numpy()
    for i, model in enumerate(model_autoreg):
        X = np.concatenate([X, model_autoreg[i].predict(X)[:, None]], axis=-1)
    log_likelihood["train"].append(poisson.logpmf(data_order["train"], X).sum(-1))

    X = data_order["valid"].iloc[:, :1].to_numpy()
    for i, model in enumerate(model_autoreg):
        X = np.concatenate([X, model_autoreg[i].predict(X)[:, None]], axis=-1)
    log_likelihood["valid"].append(poisson.logpmf(data_order["valid"], X).sum(-1))

    pbar.set_postfix(
        OrderedDict(
            [
                (
                    subset,
                    "{:.4f}".format(
                        (
                            special.logsumexp(log_likelihood[subset], 0)
                            - np.log(len(log_likelihood[subset]))
                        ).mean()
                    ),
                )
                for subset in ["train", "valid"]
            ]
        )
    )

for key in log_likelihood:
    log_likelihood[key] = np.array(log_likelihood[key])
# Out:
#   0%|          | 0/100 [00:00<?, ?order/s]

# %%
df_order = pd.DataFrame(
    orders, columns=["var_{:0=2d}".format(order + 1) for order in range(80)]
)

df_train = pd.DataFrame(
    log_likelihood["train"].T,
    columns=["order_{:0=2d}".format(order + 1) for order in range(100)],
)
df_valid = pd.DataFrame(
    log_likelihood["valid"].T,
    columns=["order_{:0=2d}".format(order + 1) for order in range(100)],
)

df_order.to_csv("outputs/xgb_order.csv", index=False)
df_train.to_csv("outputs/xgb_log_likelihood_train.csv", index=False)
df_valid.to_csv("outputs/xgb_log_likelihood_valid.csv", index=False)
# Out:
#                         var_01                   var_02  \
# 0            [broccoli]-[food]        [tie]-[accessory]
# 1         [airplane]-[vehicle]        [spoon]-[kitchen]
# 2        [teddy bear]-[indoor]  [keyboard]-[electronic]
# 3             [bowl]-[kitchen]  [microwave]-[appliance]
# 4        [toaster]-[appliance]        [broccoli]-[food]
# ..                         ...                      ...
# 95     [microwave]-[appliance]    [stop sign]-[outdoor]
# 96          [frisbee]-[sports]         [hot dog]-[food]
# 97          [bottle]-[kitchen]  [baseball bat]-[sports]
# 98  [refrigerator]-[appliance]     [toilet]-[furniture]
# 99   [parking meter]-[outdoor]        [knife]-[kitchen]
#
#                      var_03                  var_04                  var_05  \
# 0           [skis]-[sports]   [teddy bear]-[indoor]        [bowl]-[kitchen]
# 1         [tv]-[electronic]  [backpack]-[accessory]         [bus]-[vehicle]
# 2           [skis]-[sports]       [person]-[person]         [orange]-[food]
# 3           [banana]-[food]       [bed]-[furniture]  [backpack]-[accessory]
# 4   [microwave]-[appliance]   [laptop]-[electronic]     [couch]-[furniture]
# ..                      ...                     ...                     ...
# 95  [keyboard]-[electronic]  [suitcase]-[accessory]      [oven]-[appliance]
# 96    [stop sign]-[outdoor]    [airplane]-[vehicle]         [bird]-[animal]
# 97          [cup]-[kitchen]      [frisbee]-[sports]        [sheep]-[animal]
# 98        [truck]-[vehicle]         [carrot]-[food]        [bowl]-[kitchen]
# 99         [zebra]-[animal]      [sink]-[appliance]         [orange]-[food]
#
#                     var_06                     var_07  \
# 0       [sink]-[appliance]    [keyboard]-[electronic]
# 1     [surfboard]-[sports]  [parking meter]-[outdoor]
# 2        [train]-[vehicle]          [broccoli]-[food]
# 3         [clock]-[indoor]       [mouse]-[electronic]
# 4           [cow]-[animal]     [wine glass]-[kitchen]
# ..                     ...                        ...
# 95       [train]-[vehicle]       [airplane]-[vehicle]
# 96   [remote]-[electronic]             [dog]-[animal]
# 97       [bed]-[furniture]     [umbrella]-[accessory]
# 98         [book]-[indoor]         [oven]-[appliance]
# 99  [umbrella]-[accessory]    [keyboard]-[electronic]
#
#                         var_08                 var_09  \
# 0      [microwave]-[appliance]      [sandwich]-[food]
# 1            [truck]-[vehicle]       [clock]-[indoor]
# 2        [handbag]-[accessory]  [laptop]-[electronic]
# 3   [potted plant]-[furniture]         [apple]-[food]
# 4              [carrot]-[food]      [spoon]-[kitchen]
# ..                         ...                    ...
# 95            [horse]-[animal]     [sink]-[appliance]
# 96              [cow]-[animal]      [person]-[person]
# 97             [bear]-[animal]      [person]-[person]
# 98    [fire hydrant]-[outdoor]      [tv]-[electronic]
# 99          [frisbee]-[sports]   [toilet]-[furniture]
#
#                         var_10  ...                     var_71  \
# 0           [oven]-[appliance]  ...  [parking meter]-[outdoor]
# 1              [carrot]-[food]  ...          [bench]-[outdoor]
# 2   [potted plant]-[furniture]  ...            [bear]-[animal]
# 3            [bench]-[outdoor]  ...           [boat]-[vehicle]
# 4          [chair]-[furniture]  ...            [bird]-[animal]
# ..                         ...  ...                        ...
# 95    [fire hydrant]-[outdoor]  ...              [cake]-[food]
# 96         [scissors]-[indoor]  ...          [knife]-[kitchen]
# 97             [bird]-[animal]  ...     [backpack]-[accessory]
# 98        [airplane]-[vehicle]  ...          [tie]-[accessory]
# 99             [book]-[indoor]  ...             [apple]-[food]
#
#                     var_72                      var_73  \
# 0    [toaster]-[appliance]       [skateboard]-[sports]
# 1       [giraffe]-[animal]  [potted plant]-[furniture]
# 2       [frisbee]-[sports]      [backpack]-[accessory]
# 3        [tv]-[electronic]              [pizza]-[food]
# 4         [fork]-[kitchen]      [sports ball]-[sports]
# ..                     ...                         ...
# 95     [bicycle]-[vehicle]         [chair]-[furniture]
# 96         [bus]-[vehicle]   [baseball glove]-[sports]
# 97          [cat]-[animal]           [knife]-[kitchen]
# 98  [sports ball]-[sports]            [hot dog]-[food]
# 99         [vase]-[indoor]      [sports ball]-[sports]
#
#                        var_74                      var_75  \
# 0             [bear]-[animal]   [traffic light]-[outdoor]
# 1         [elephant]-[animal]              [cat]-[animal]
# 2              [dog]-[animal]         [chair]-[furniture]
# 3          [oven]-[appliance]     [baseball bat]-[sports]
# 4      [umbrella]-[accessory]       [skateboard]-[sports]
# ..                        ...                         ...
# 95  [baseball glove]-[sports]            [hot dog]-[food]
# 96      [skateboard]-[sports]      [sports ball]-[sports]
# 97        [elephant]-[animal]  [potted plant]-[furniture]
# 98       [mouse]-[electronic]   [parking meter]-[outdoor]
# 99             [dog]-[animal]             [cup]-[kitchen]
#
#                        var_76                     var_77  \
# 0         [scissors]-[indoor]  [cell phone]-[electronic]
# 1            [hot dog]-[food]        [scissors]-[indoor]
# 2       [stop sign]-[outdoor]  [cell phone]-[electronic]
# 3             [vase]-[indoor]          [person]-[person]
# 4             [vase]-[indoor]       [mouse]-[electronic]
# ..                        ...                        ...
# 95          [tv]-[electronic]             [cat]-[animal]
# 96  [cell phone]-[electronic]          [broccoli]-[food]
# 97       [mouse]-[electronic]      [teddy bear]-[indoor]
# 98   [tennis racket]-[sports]      [toothbrush]-[indoor]
# 99       [snowboard]-[sports]      [skateboard]-[sports]
#
#                      var_78                      var_79  \
# 0      [mouse]-[electronic]              [apple]-[food]
# 1    [motorcycle]-[vehicle]              [apple]-[food]
# 2      [airplane]-[vehicle]             [bird]-[animal]
# 3     [skateboard]-[sports]             [bus]-[vehicle]
# 4             [cake]-[food]  [potted plant]-[furniture]
# ..                      ...                         ...
# 95    [hair drier]-[indoor]            [bowl]-[kitchen]
# 96      [chair]-[furniture]           [bed]-[furniture]
# 97  [keyboard]-[electronic]               [cake]-[food]
# 98          [cup]-[kitchen]            [horse]-[animal]
# 99      [elephant]-[animal]       [handbag]-[accessory]
#
#                         var_80
# 0            [spoon]-[kitchen]
# 1      [microwave]-[appliance]
# 2         [toilet]-[furniture]
# 3              [kite]-[sports]
# 4            [bench]-[outdoor]
# ..                         ...
# 95  [refrigerator]-[appliance]
# 96            [clock]-[indoor]
# 97              [pizza]-[food]
# 98         [bicycle]-[vehicle]
# 99   [traffic light]-[outdoor]
#
# [100 rows x 80 columns]
